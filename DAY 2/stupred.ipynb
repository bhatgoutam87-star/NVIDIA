# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    accuracy_score,
    classification_report,
    confusion_matrix
)
import numpy as np

# %%
df = pd.read_excel("student_marks_10000 (1).xlsx")

# %%
label_encoders = {}

for column in df.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le

# %%
# REGRESSION
# Predict Final Marks
# -----------------------------

# Assume 'Final_Marks' is the target column
X_reg = df.drop(["Final_Marks", "Pass_Fail"], axis=1) # Exclude 'Pass_Fail' from regression features
y_reg = df["Final_Marks"]

X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_reg, y_reg, test_size=0.2, random_state=42
)

reg_model = LinearRegression()
reg_model.fit(X_train_reg, y_train_reg)

y_pred_reg = reg_model.predict(X_test_reg)

print("\n===== REGRESSION RESULTS ====")
print("MAE :", mean_absolute_error(y_test_reg, y_pred_reg))
print("MSE :", mean_squared_error(y_test_reg, y_pred_reg))
print("RMSE:", np.sqrt(mean_squared_error(y_test_reg, y_pred_reg)))
print("R² Score:", r2_score(y_test_reg, y_pred_reg))
# -----------------------------
# Predict Final Marks for New Student
# -----------------------------
# New student data
# Ensure all columns of X_reg are present and in the correct order.
new_student = pd.DataFrame({
    'Student_ID': [0], # Placeholder for a new student ID
    'Student_Name': [label_encoders['Student_Name'].transform([label_encoders['Student_Name'].classes_[0]])[0]], # Use a known student name from the encoder's classes
    'Study_Hours': [6],
    'Attendance': [85],
    'Assignment_Score': [8], # Renamed 'Assignments' to 'Assignment_Score'
    'Result': [label_encoders['Result'].transform(['Pass'])[0]] # Placeholder for 'Result'
})

# Predict final marks
predicted_marks = reg_model.predict(new_student)

print("Predicted Final Marks:", round(predicted_marks[0], 2))
# Out:
# ===== REGRESSION RESULTS ====
# MAE : 3.618428993190744
# MSE : 20.553142237429334
# RMSE: 4.5335573490835355
# R² Score: 0.8817225563144354
# Predicted Final Marks: 51.67

# %%
print("Accuracy:", accuracy_score(y_test_clf, y_pred_clf))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test_clf, y_pred_clf))

print("\nClassification Report:")
print(classification_report(y_test_clf, y_pred_clf))

# The 'new_student' DataFrame was not defined in the previous cell
# due to a KeyError. To allow this cell to run, we'll define a
# new_student DataFrame here using the values already entered by the user
# in the previous cell's prompt (available in kernel state) and default/placeholder
# values for other necessary features for X_clf.

# Features in X_clf (from kernel state):
# Student_ID, Student_Name (encoded), Study_Hours, Attendance, Assignment_Score, Result (encoded)

# Using values from previous interactive inputs (from kernel state)
# study_hours = 10.0
# attendance = 78.0
# assignments = 7.0 (mapping to Assignment_Score)

# Create new_student for classification prediction.
# Ensure all columns of X_clf are present and in the correct order.
new_student = pd.DataFrame({
    'Student_ID': [0], # Placeholder for a new student ID
    'Student_Name': [label_encoders['Student_Name'].transform([label_encoders['Student_Name'].classes_[0]])[0]], # Use a known student name from the encoder's classes
    'Study_Hours': [study_hours], # Use value from previous input
    'Attendance': [attendance], # Use value from previous input
    'Assignment_Score': [assignments], # Use value from previous input (mapped to Assignment_Score)
    'Result': [label_encoders['Result'].transform(['Pass'])[0]] # Encoded placeholder for 'Result'
})

predicted_status = clf_model.predict(new_student)

if predicted_status[0] == 1:
    print("Prediction: PASS")
else:
    print("Prediction: FAIL")
# Out:
# Accuracy: 0.991
#
# Confusion Matrix:
# [[   8   15]
#  [   3 1974]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.35      0.47        23
#            1       0.99      1.00      1.00      1977
#
#     accuracy                           0.99      2000
#    macro avg       0.86      0.67      0.73      2000
# weighted avg       0.99      0.99      0.99      2000
#
# Prediction: PASS
